# %% [markdown]
# # Import

# %%
# %pylab --no-import-all notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import qutip as qp
from importlib import reload
import scipy

# %% [markdown]
# # Global parameters

# %%
plt.rcParams['text.usetex'] = False  # True - for pretty graphs

# %% [markdown]
# # Units convention
# Energy unit = $10^{-9} \frac{\text{EnergySI}}{h}$ GHz $\newline$
# time = $10^{-9}$timeSI - [ns]

# %% [markdown]
# # Single transmon

# %%
import transmon_simulations_lib.single_transmon.transmon
reload(transmon_simulations_lib.single_transmon.transmon)
from transmon_simulations_lib.single_transmon.transmon import Transmon

import transmon_simulations_lib.single_transmon.tmon_eigensystem
reload(transmon_simulations_lib.single_transmon.tmon_eigensystem)
from transmon_simulations_lib.single_transmon.tmon_eigensystem import TmonPars

from transmon_simulations_lib.custom_ops import raising_op, lowering_op

# %% [markdown]
# ## Tmon & num parameters

# %%
Ec=0.6
Ej=28
alpha=0.2
gamma_rel = 10e-6
gamma_phi = 20e-6

Nc = 10
dims = 2*Nc + 1

# %% [markdown]
# ## Eigenvectors projection on self. Case I: without potential shift from flux

# %% [markdown]
# __**Case I**__ <br>
# *Used in current code*
# $$ \phi_{ext} = 2 \pi \frac{\Phi_{ext}}{\Phi_0} $$
# where $\Phi_0 = h/2e $ - flux quantum in SI
# $$ H = E_C n^2 - E_J sign\left( cos{\left( \frac{\phi_{ext}}{2}\right)} \right)
# \sqrt{1 + \alpha^2 + 2 \alpha \cos{\left( \frac{\phi_{ext}}{2} \right)}} \cos{\phi} $$
# where
# $$\phi = \frac{\phi_1 + \phi_2}{2} $$
# $\phi_i$ - phase drop accross i-th JJ
# where $\phi$ - is qubit branch flux canonical variable<br>
# $\alpha = E_{J1}/E_{J2} < 1$ is the ratio between smaller JJ energy to larger.

# %%
phi_Ext_list = np.linspace(0, 8*np.pi, 101)
pars_list = [TmonPars(Ec, Ej, alpha, phi, 0, gamma_rel, gamma_phi) for phi in phi_Ext_list]
tr1 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols1 = tr1.solve()
res_list1 = np.array([sol.evecs for sol in sols1])
n_entries = len(res_list1)
fig, ax = plt.subplots(1,1)
goodness1 = np.zeros(res_list1.shape, dtype=complex)

for i in range(res_list1.shape[0]):
    for j in range(res_list1.shape[1]):
        goodness1[i,j] = np.abs((res_list1[i,j].dag() * res_list1[0,j])[0,0])

for vec_idx, vec_goodness in enumerate(goodness1.T):
    ax.plot(phi_Ext_list, np.abs(vec_goodness), label=r"$\left\langle %d | %d(\phi) \right\rangle  $"%(vec_idx,vec_idx))
ax.legend()
ax.set_title(r"for Nc = 15 or $dim(\mathcal{H}) = 31 $   CASE 1")

# %% [markdown]
# ## Eigenvectors projection on self. Case II: potential well shifts from flux

# %% [markdown]
# __**Case II**__
# *utilizing static quantization of transmon by Koch et.al https://doi.org/10.1103/PhysRevA.76.042319*
# $$ H = E_C n^2 - E_J sgn({cos{\left( \frac{\phi_{ext}}{2} \right)}}) \sqrt{1 + \alpha^2 + 2 \alpha \cos{\left( \frac{\phi_{ext}}{2} \right)}} \cos{\left( \phi - \phi_0 \right) } $$
# where $\phi_0 = \arctan{\left( d \tan{\left( \frac{\phi_{ext}}{2} \right)} \right)} $ and $d = \frac{1-\alpha}{1+\alpha}$ <br>

# %%
pars_list = [TmonPars(Ec, Ej, alpha, 0, phi, gamma_rel, gamma_phi) for phi in phi_Ext_list]
tr2 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols2 = tr2.solve()
res_list2 = np.array([sol.evecs for sol in sols2])
n_entries = len(res_list2)
fig, ax = plt.subplots(1,1)
goodness2 = np.zeros(res_list2.shape, dtype=complex)

for i in range(res_list2.shape[0]):
    for j in range(res_list2.shape[1]):
        goodness2[i,j] = np.abs((res_list2[i,j].dag() * res_list2[0,j])[0,0])

for vec_idx, vec_goodness in enumerate(goodness2.T):
    ax.plot(phi_Ext_list, np.abs(vec_goodness), label=r"$\left\langle %d | %d(\phi) \right\rangle  $"%(vec_idx,vec_idx))
ax.legend()
ax.set_title(r"for Nc = 15 or $dim(\mathcal{H}) = 31 $   CASE 2")

# %% [markdown]
# ## Case I and Case II E01 energy comparison

# %%
# plt.rcParams['text.usetex'] = True
E01_1 = np.array([sol.E01() for sol in sols1])
E01_2 = np.array([sol.E01() for sol in sols2])
fig, ax = plt.subplots(1,1)
ax.plot(phi_Ext_list, np.abs(E01_1 - E01_2)/E01_1, label="rel diff")
ax.legend()

# %% [markdown]
# ## Eigenvectors projection on self. Case III: intermediate, irrotational gauge.

# %% [markdown]
# **Case III**
# *utilizing You, X.,et.al (Koch included) (2019). https://doi.org/10.1103/PhysRevB.99.174512*
#
# Written in branch variables *branch* fluxes (G. Burkard et. al 2004 https://journals.aps.org/prb/abstract/10.1103/PhysRevB.69.064503) instead of *node* fluxes (Devoret). Each branch is oriented and each loop is oriented as well. Their relative orientation is captured by *mesh matrix* $\mathbf{R}$:
# $$ \left( \mathbf{R} \right)_{i,j} = \cases{
# 1  \;\;\;\; \Phi_j \in L_i, \text{cooriented branch and loop}\\
# -1 \;\;\; \Phi_j \in L_i, \text{contraoriented branch and loop}\\
# 0 \;\;\;\; \Phi_j \notin L_i, \text{loop does include branch}\\
# } $$

# %% [markdown]
# R matrix connects branch fluxes and loops fluxes as follows:
#
# $$ \mathbf{\Phi_e}(t)_i = \left(\mathbf{R}\right)_{i,j} \; \mathbf{\Phi}(t)_j $$
# where $ \mathbf{\Phi_e}(t)_i  $ - flux through i-th loop (i goes from 1 to F - mesh number of a circuit).<br>
# Mesh - set of loops where each loop does not contain other loop<br>
# and $\mathbf{\Phi}(t)_j$ - branch flux of j-th branch
#
# Due to the fact that we have F contraints for branch fluxes generated by $\mathbf{R}$ above we will declare new (N-F) flux variables  $\tilde{\mathbf{\Phi}}$:
# $$ \tilde{\mathbf{\Phi}} = \mathbf{M} \mathbf{\Phi} $$
# where $\mathbf{M}$ - is (N-F)xN matrix that is to be found to eliminate $\dot{\Phi}_e(t)_i$ resulting Hamiltonian.

# %% [markdown]
# Declaring new vector
# $$\tilde{\mathbf{\Phi}}_{+} = \left(
# \matrix{
# \tilde{\mathbf{\Phi}} \\
# \mathbf{\Phi}_e
# }
# \right)
# $$

# %% [markdown]
# and the new matrix
# $$\mathbf{M}_{+} = \left(
# \matrix{
# \mathbf{M} \\
# \mathbf{R}
# }
# \right)
# $$
#
# we can write down both degrees of freedom and constraints as a single equation:
#
# $$\tilde{\mathbf{\Phi}}_{+} = \mathbf{M}_{+} \mathbf{\Phi} $$

# %% [markdown]
# kinetic energy in branch represention (N branches):
# $$ \mathcal{L}_k = \frac{1}{2}\dot{\mathbf{\Phi}}^T \mathbf{C} \dot{\mathbf{\Phi}} $$
# where $ \mathbf{C} = diag\left(C_1, C_2, ..., C_N\right) $ matrix of branches capacitances.

# %% [markdown]
# Moving towards canonical variables and external fluxes:
# $$\dot{\mathbf{\Phi}} = \mathbf{M}_{+}^{-1} \dot{\tilde{\mathbf{\Phi}}}_{+} $$
# <br>
# $$ \mathcal{L}_{\text{K}} = \frac{1}{2}\dot{\tilde{\mathbf{\Phi}}}_{+}^T \mathbf{C}_{\text{eff}} \dot{\tilde{\mathbf{\Phi}}}_{+} $$
# where
# $$\mathbf{C}_{\text{eff}} = (\mathbf{M}_{+}^{-1})^T \mathbf{C} \left(\mathbf{M}_{+}^{-1}\right) $$

# %% [markdown]
# Since we wish to decouple $\dot{\tilde{\mathbf{\Phi}}}$ and $\dot{\mathbf{\Phi}}_e$
# than $\mathbf{C}_{\text{eff}}$ has to be block-diagonal with blocks (N-F)x(N-F) and FxF.
# Former corresponding to kinetic energy based on new canonical variables $\dot{\tilde{\mathbf{\Phi}}}$ and the latter will be excluded from Lagrangian as a total derivative of time only dependent function.<br>
# Block-diagonal requirement is also applies to the inverse of $\mathbf{C}_{\text{eff}}$:

# %% [markdown]
# $$ \mathbf{C}_{\text{eff}}^{-1} =  (\mathbf{M}_{+}) \mathbf{C}^{-1} \left(\mathbf{M}_{+} \right)^T = \left(
# \matrix{
# \mathbf{M} \\
# \mathbf{R}
# }
# \right)
# \mathbf{C}^{-1}
# \left(
# \matrix{
# \mathbf{M}^T & \mathbf{R}^T
# }
# \right) =
# \left(
# \matrix{
# \mathbf{M}\mathbf{C}^{-1}\mathbf{M} & \mathbf{M}\mathbf{C}^{-1}\mathbf{R}^T \\
# \mathbf{R}\mathbf{C}^{-1}\mathbf{M} & \mathbf{R}\mathbf{C}^{-1}\mathbf{R}
# }
# \right)
# $$

# %% [markdown]
# Hence we have to find atleast one matrix that satisfy:
# $$\mathbf{R}\mathbf{C}^{-1}\mathbf{M}^T = 0$$
#
# Speaking in terms of linear argebra: rows of $\mathbf{M}$ is the null space of $\mathbf{R}\mathbf{C}^{-1}$ operator.

# %% [markdown]
# Consider the following schematics where leftmost JJ is substituted with simple capacitor C

# %% [markdown]
# ![title](Case_3.png)

# %% [markdown]
# $$\mathbf{R} =
# \left(
# \matrix{
# 1 & -1 & 0 \\
# 0 & 1 & -1
# }
# \right)
# $$
# $$\mathbf{C}^{-1} = diag\left( C_1^{-1},C_2^{-1},C_{3}^{-1} \right)$$
# $$ \mathbf{R} \mathbf{C}^{-1} =
# \left(
# \matrix{
# C_1^{-1} & -C_2^{-1} & 0 \\
# 0 & C_2^{-1} & -C_3^{-1}
# }
# \right)
# $$
# <br>
# from here we can deduce that (properly normalized by $C_{\Sigma} = \Sigma C_i$:
# $$ M = \frac{1}{C_{\Sigma}}
# \left(
# \matrix{C_1 & C_2 & C_3 }
# \right) $$
# <br>
# is the solution that satisfies
# $$\mathbf{R}\mathbf{C}^{-1}\mathbf{M}^T = 0$$

# %% [markdown]
# Finally we have only one "free" branch variable: <br>
# $ \tilde{\phi} = \mathbf{M} \mathbf{\Phi} = \sum_{j=1}^{N_{br}=3} \frac{C_j}{C_{\Sigma}}\Phi_j$
#
# <br>
# Finding equation for $\mathbf{C}_{\text{eff}}$:

# %% [markdown]
# $$ \mathbf{M}_{+} =
# \left(
# \matrix{
# \mathbf{M} \\
# \mathbf{R}
# }
# \right) =
# \left(
# \matrix{
# \frac{C_1}{C_{\Sigma}} & \frac{C_2}{C_{\Sigma}} & \frac{C_3}{C_{\Sigma}}\\
# 1 & -1 & 0 \\
# 0 & 1 & -1
# }
# \right)
# $$

# %% [markdown]
# $$ (\mathbf{M}_{+})^{-1} =
# \left(
# \matrix{
# 1 & \frac{C_2 + C_3}{C_{\Sigma}} & \frac{C_3}{C_{\Sigma}} \\
# 1 & -\frac{C_1}{C_{\Sigma}} & \frac{C_3}{C_{\Sigma}} \\
# 1 & -\frac{C_1}{C_{\Sigma}} & -\frac{C_1 + C_2}{C_{\Sigma}}
# }
# \right) $$

# %% [markdown]
# <br>
# And finally
# $$\mathbf{C}_{\text{eff}} =
# \left(
# \matrix{
# C_{\Sigma} & 0 & 0 \\
# 0 & \frac{C_1(C_2 + C_3)}{C_{\Sigma}} & \frac{C_1 C_3}{C_{\Sigma}} \\
# 0 & \frac{C_1 C_3}{C_{\Sigma}} &\frac{(С_1+С_2)C_3}{C_{\Sigma}}
# }
# \right)
# $$

# %% [markdown]
# $$\mathbf{\Phi} = \mathbf{M}_{+}^{-1} \tilde{\mathbf{\Phi}}_{+} $$
# or

# %% [markdown]
# $$ \left(
# \matrix{
# \Phi_1 \\
# \Phi_2 \\
# \Phi_3
# }
# \right) =
# (\mathbf{M}_{+})^{-1}
# \left(\matrix{
# \tilde{\phi} \\
# \Phi_e^1 \\
# \Phi_e^2
# }
# \right) $$

# %% [markdown]
# Total Hamiltonian in this case will be
#
# $$ H =  E_C n^2 -
# E_{J2}\cos{\left( \tilde{\phi} -\frac{C_1}{C_{\Sigma}}\Phi_e^{1} + \frac{C_3}{C_{\Sigma}}\Phi_e^{2} \right)}
# - E_{J3}\cos{\left(\tilde{\phi}  -\frac{C_1}{C_{\Sigma}}\Phi_e^{1} -\frac{C_1 + C_2}{C_{\Sigma}}\Phi_e^{2}\right)} $$
# where $E_C = 2e^2/C_{\Sigma}$

# %% [markdown]
# or in notation of Tmon:
# $$ H =  E_C n^2 -
# E_{J1}\cos{\left( \tilde{\phi} -\frac{C_{sh}}{C_{\Sigma}}\Phi_e^{1} + \frac{C_{J2}}{C_{\Sigma}}\Phi_e^{2} \right)}
# - E_{J2}\cos{\left(\tilde{\phi}  -\frac{C_{sh}}{C_{\Sigma}}\Phi_e^{1} -\frac{C_{sh} + C_{J1}}{C_{\Sigma}}\Phi_e^{2}\right)} $$

# %% [markdown]
# Firstly, repeating result for Case I and Case II since parameters generation code is slightly different.

# %% [markdown]
# ### Repeat Case I and Case II

# %%
pars_list = []
for phi_Ext in phi_Ext_list:
    phi_Ext1 = phi_Ext
    phi_Ext2 = 0
    pars_list.append(
        TmonPars(Ec, Ej, alpha, phi_Ext1, phi_Ext2, gamma_rel, gamma_phi)
    )
tr31 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols31 = tr31.solve()
res_list3 = np.array([sol.evecs for sol in sols31])
n_entries = len(res_list3)
fig, ax = plt.subplots(1,1)
goodness3 = np.zeros(res_list3.shape, dtype=complex)

for i in range(res_list3.shape[0]):
    for j in range(res_list3.shape[1]):
        goodness3[i,j] = np.abs((res_list3[i,j].dag() * res_list3[0,j])[0,0])

for vec_idx, vec_goodness in enumerate(goodness3.T):
    ax.plot(phi_Ext_list, np.abs(vec_goodness), label=r"$\left\langle %d | %d(\phi) \right\rangle  $"%(vec_idx,vec_idx))
ax.legend()
ax.set_title(r"for Nc = 15 or $dim(\mathcal{H}) = 31 $   CASE 3.1")
ax.grid()

# %%
pars_list = []
for phi_Ext in phi_Ext_list:
    phi_Ext1 = 0
    phi_Ext2 = phi_Ext
    pars_list.append(
        TmonPars(Ec, Ej, alpha, phi_Ext1, phi_Ext2, gamma_rel, gamma_phi)
    )
tr32 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols32 = tr32.solve()
res_list3 = np.array([sol.evecs for sol in sols32])
n_entries = len(res_list3)
fig, ax = plt.subplots(1,1)
goodness3 = np.zeros(res_list3.shape, dtype=complex)

for i in range(res_list3.shape[0]):
    for j in range(res_list3.shape[1]):
        goodness3[i,j] = np.abs((res_list3[i,j].dag() * res_list3[0,j])[0,0])

for vec_idx, vec_goodness in enumerate(goodness3.T):
    ax.plot(phi_Ext_list, np.abs(vec_goodness), label=r"$\left\langle %d | %d(\phi) \right\rangle  $"%(vec_idx,vec_idx))
ax.legend()
ax.set_title(r"for Nc = 15 or $dim(\mathcal{H}) = 31 $   CASE 3.2")
ax.grid()

# %% [markdown]
# Next calculations are based on parameters of the real design
# $$ C_{sh} \approx 130 \; \text{fF} $$
# $$ C_{J1} \approx 0.5  \; \text{fF} \ll C_{sh} $$
# $$ C_{J2} \approx \alpha C_{J1} \ll C_{sh} $$

# %% [markdown]
# %%latex
# yet this guess is barely close to reality due to the fact that we have distributed capacitance.
# Distributed capacitance case is examined in
# \cite{Riwar2021}

# %% [markdown]
# ### Phi_1 = Phi_2

# %%
Csh = 130e-15
CJ1 = 0.5e-15
CJ2 = CJ1* alpha
Csigma = Csh + CJ1 + CJ2
pars_list = []
for phi_Ext in phi_Ext_list:
    phi_Ext1 = phi_Ext
    phi_Ext2 = phi_Ext
    # `mul` part is based on equation (2) from http://arxiv.org/abs/2103.03577
    phi_Ext1 = (Csh/Csigma*phi_Ext1 - CJ2/Csigma*phi_Ext2)
    phi_Ext2 = (Csh/Csigma*phi_Ext1 - (CJ1 + Csh)/Csigma*phi_Ext2)
    pars_list.append(
        TmonPars(Ec, Ej, alpha, phi_Ext1, phi_Ext2, gamma_rel, gamma_phi)
    )
tr3 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols3 = tr3.solve()
res_list3 = np.array([sol.evecs for sol in sols3])
n_entries = len(res_list3)
fig, ax = plt.subplots(1,1)
goodness3 = np.zeros(res_list3.shape, dtype=complex)

for i in range(res_list3.shape[0]):
    for j in range(res_list3.shape[1]):
        goodness3[i,j] = np.abs((res_list3[i,j].dag() * res_list3[0,j])[0,0])

for vec_idx, vec_goodness in enumerate(goodness3.T):
    ax.plot(phi_Ext_list, np.abs(vec_goodness), label=r"$\left\langle %d | %d(\phi) \right\rangle  $"%(vec_idx,vec_idx))
ax.legend()
ax.set_title(r"for Nc = 15 or $dim(\mathcal{H}) = 31 $   CASE 3")
ax.grid()

# %% [markdown]
# ### Summary

# %% [markdown]
# solutions

# %% [markdown]
# Case I

# %%
phi_Ext_list = np.linspace(0, 8*np.pi, 401)
pars_list = [TmonPars(Ec, Ej, alpha, phi, 0, gamma_rel, gamma_phi) for phi in phi_Ext_list]
tr1 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols1 = tr1.solve()

# %% [markdown]
# Case II

# %%
pars_list = [TmonPars(Ec, Ej, alpha, 0, phi, gamma_rel, gamma_phi) for phi in phi_Ext_list]
tr2 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols2 = tr2.solve()

# %% [markdown]
# Case III

# %%
Csh = 130e-15
CJ1 = 0.5e-15
CJ2 = CJ1* alpha
Csigma = Csh + CJ1 + CJ2
pars_list = []
for phi_Ext in phi_Ext_list:
    phi_Ext1 = phi_Ext
    phi_Ext2 = phi_Ext
    # `mul` part is based on equation (2) from http://arxiv.org/abs/2103.03577
    phi_Ext1 = (Csh/Csigma*phi_Ext1 - CJ2/Csigma*phi_Ext2)
    phi_Ext2 = (Csh/Csigma*phi_Ext1 - (CJ1 + Csh)/Csigma*phi_Ext2)
    pars_list.append(
        TmonPars(Ec, Ej, alpha, phi_Ext1, phi_Ext2, gamma_rel, gamma_phi)
    )
tr3 = Transmon(pars_list, Nc=Nc, res_trunc=4)
sols3 = tr3.solve()

# %% [markdown]
# plotting

# %%
fig, axs = plt.subplots(4,1, sharex=True)
for sols_idx, sols in enumerate([sols1, sols2, sols3]):
    axs[0].plot(phi_Ext_list, [sol.E01() for sol in sols], label=r"$E_{01}$ Case " + str(sols_idx+1) )
    eg_overlap = [sols[0].g_state().overlap(sol.e_state()) for sol in sols]
    ee_overlap = [sols[0].e_state().overlap(sol.e_state()) for sol in sols]
    fe_overlap = [sols[0].f_state().overlap(sol.e_state()) for sol in sols]
    axs[sols_idx+1].plot(phi_Ext_list, np.abs(eg_overlap)**2, label=r"$\left< g(0) \vert e(\phi_{e}) \right>$")
    axs[sols_idx+1].plot(phi_Ext_list, np.abs(ee_overlap)**2, label=r"$\left< e(0) \vert e(\phi_{e}) \right>$")
    axs[sols_idx+1].plot(phi_Ext_list, np.abs(fe_overlap)**2, label=r"$\left< f(0) \vert e(\phi_{e}) \right>$")
for ax_idx, ax in enumerate(axs):
    ax.legend()
    ax.grid()
    if ax_idx > 0:
        ax.set_title("CASE " + str(ax_idx))

# %% [markdown]
# Case I:
# $$ H_J = -E_J sign\left( cos{\left( \frac{\phi_{ext}}{2}\right)} \right)
# \sqrt{1 + \alpha^2 + 2 \alpha \cos{\left( \frac{\phi_{ext}}{2} \right)}} \cos{\phi} $$
# where
# $$\phi = \frac{\phi_1 + \phi_2}{2} $$
# $\phi_i$ - phase drop accross i-th JJ
# where $\phi$ - is qubit branch flux canonical variable<br>
# $\alpha = E_{J1}/E_{J2} < 1$ is the ratio between smaller JJ energy to larger.

# %% [markdown]
# Case II:
# $$H_J =  -E_J sgn({cos{\left( \frac{\phi_{ext}}{2} \right)}}) \sqrt{1 + \alpha^2 + 2 \alpha \cos{\left( \frac{\phi_{ext}}{2} \right)}} \cos{\left( \phi - \phi_0 \right) } $$
# where $\phi_0 = \arctan{\left( d \tan{\left( \frac{\phi_{ext}}{2} \right)} \right)} $ and $d = \frac{1-\alpha}{1+\alpha}$

# %% [markdown]
# Case III:
# $$ H_J = -E_{J1}\cos{\left( \tilde{\phi} -\frac{C_{sh}}{C_{\Sigma}}\phi_0 + \frac{C_{J2}}{C_{\Sigma}}\phi_0 \right)}
# - \alpha E_J \cos{\left(\tilde{\phi}  -\frac{C_{sh}}{C_{\Sigma}}\phi_0 -\frac{C_{sh} + C_{J1}}{C_{\Sigma}}\phi_0 \right)} $$ <br>
# in case with <br>
# $C_{sh} = 130 \times 10^{-15}$ F <br>
# $C_{J1} = 0.5 \times 10^{-15}$ F <br>
# $C_{J2} = \alpha C_{J1}$ F

# %% [markdown]
# # Berry curvature

# %% [markdown]
# ## Analytic expression

# %% [markdown]
# For eigenstate with index $n$ there is a quantity called Berry's phase (Berry himself called it "geometrical phase") that has following definition:
# $$ \gamma_n(P_{a,b}) = i \int\limits_{P_{a,b}}  \left< n(\vec{\textbf{R}}) \left| \nabla_{\vec{{\textbf{R}}}} \right| n(\vec{\textbf{R}})\right>$$
# Integral along path $P_{a,b}$ that connects points $a$ and $b$ in Hamiltonian parameter space.
# Parameters are changed adiabatically, such that
# $$ \left| \partial_t \vec{\textbf{R}}\right| \ll \frac{h}{E_1 - E_2} $$
# where $E_1$ and $E_2$ are energies of the levels related to problem. Also $\vec{\textbf{R}}$ chosen dimensionless.

# %% [markdown]
# Related quantity called Berry curvature is a (0,2) tensor in parameters space:
# $$ \Omega_{n,\mu \nu}(\vec{\textbf{R}}) = \partial_{\mu} A_{n,\nu}(\vec{\textbf{R}}) - \partial_{\nu} A_{n,\mu}(\vec{\textbf{R}}) $$
# where

# %% [markdown]
# $$\vec{\textbf{A}}_{n,\mu}
# (\vec{\textbf{R}}) = \left< n(\vec{\textbf{R}}) \left| \nabla_{\mu} \right| n(\vec{\textbf{R}})\right> $$

# %% [markdown]
# called a Berry's path.

# %% [markdown]
# The idea is that Berry's curvature is U(1) invariant while Berry's path is not.
# Hence, explicitly U(1) invariant expression for Berry's phase (using Stoke's theorem) for path that is simple cycle:
# $$ \gamma_n(C) = \int\limits_{\partial S = C} d\textbf{S} \; \mathbf{\Omega}_{n} $$

# %% [markdown]
# From derivation of a Berry's path it can be shown that (utilizing second order perturbation theory to calculate derivatives at given parameter-space point):
# $$ \Omega_{n,\mu,nu}(R) = i \sum_{n'
# \neq n}\frac{
# \langle n|\partial H / \partial R_{\mu}|n'\rangle \langle n'|\partial H / \partial R_{\nu} | n\rangle  -
# \langle n|\partial H / \partial R_{\nu}|n'\rangle \langle n'|\partial H / \partial R_{\mu} | n\rangle
# }
# {(E_n - E_{n'})^2}
# $$

# %% [markdown]
# ## Definition of the parameter space

# %% [markdown]
# Three parameters of Hamiltonian are chosen:<br>
# $\Omega \in [0, \infty]$ - external drive amplitude <br>
# $\varphi_d \in [0,2\pi)$ - external drive phase <br>
# $\phi_{ext} \in \mathds{R}$ - external flux value

# %% [markdown]
# Hamiltonian can be written as:
# $$ H/h = E_C n^2 - E_{J1}\cos{(\phi - \alpha_1 \phi_{ext})} - E_{J2}\cos{(\phi - \alpha_2 \phi_{ext})} + n g \Omega \cos{(\omega_d t + \varphi_d)}$$
# where
# $\alpha_1, \alpha_2 \in \mathds{R}$ - arbitrary real numbers
# Columb calibration assumed to be utilized for Hamiltonian quantization for qubit with distributed capacitor geometry. This choice is dictated from \cite{Riwar2021}

# %% [markdown]
# ## Problem for test

# %% [markdown]
# %%latex
# We will consider adiabatic evolution of non-relaxating qubit in parameter space. Evolution will be calculated along closed 3D trajectory.
# Dynamics will be obtained from direct numerical solution of the Shrodingher equation.
# Then we obtain Berry phase via 2 means:
# 1. From numerical solution Berry phase will be extracted by substracting dynamical phase that will also be calculated numerically.
# 2. Direct calculation of path (calculated numerically, derivative will be approximated by finite difference scheme)
# 3. Area integral of Berry's curvature (curvature will be calculated exactly with formula above)

# %% [markdown]
# trajectory is an ellips in 3d that touches coordinate origin.

# %% [markdown]
# $$x = A_x \cos{\alpha}(1+\cos{(\omega t}))$$
# $$y = A_y \sin{(\omega t)}$$
# $$z = A_x \sin{\alpha}(1+\cos{(\omega t)})$$

# %% [markdown]
# ### trajectory parameters and speed definition

# %%
Ax = 20e-3*anh
Ay = 10e-2*anh
v_adiab = 0.001*(1/anh)
omega = v_adiab*2*np.pi

tr = Transmon([TmonPars(Ec, Ej, alpha, 0,0,0,0)], Nc=Nc)
sols = tr.solve()
omega_d = sols[0].evals_arr[1]
angle = np.pi/6  # 30 degree
alpha1 = 0.3
alpha2 = 0.7

tlist = np.linspace(0, 2*np.pi/omega, 10001)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12892\1291680098.py in <module>
#       5
#       6 tr = Transmon([TmonPars(Ec, Ej, alpha, 0,0,0,0)], Nc=Nc)
# ----> 7 sols = tr.solve()
#       8 omega_d = sols[0].evals_arr[1]
#       9 angle = np.pi/6  # 30 degree
#
# ~\Documents\GitHub\Examples\transmon_simulations_lib\single_transmon\transmon.py in solve(self, sparse)
#     161         result = []
#     162
# --> 163         for pars_pt in tqdm.tqdm_notebook(self.pars_list):
#     164             try:
#     165                 solution = self._eigsys_sol_cache[pars_pt]
#
# ~\.conda\envs\qp-nbs\lib\site-packages\tqdm\__init__.py in tqdm_notebook(*args, **kwargs)
#      26          "Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`",
#      27          TqdmDeprecationWarning, stacklevel=2)
# ---> 28     return _tqdm_notebook(*args, **kwargs)
#      29
#      30
#
# ~\.conda\envs\qp-nbs\lib\site-packages\tqdm\notebook.py in __init__(self, *args, **kwargs)
#     240         unit_scale = 1 if self.unit_scale is True else self.unit_scale or 1
#     241         total = self.total * unit_scale if self.total else self.total
# --> 242         self.container = self.status_printer(self.fp, total, self.desc, self.ncols)
#     243         self.container.pbar = proxy(self)
#     244         self.displayed = False
#
# ~\.conda\envs\qp-nbs\lib\site-packages\tqdm\notebook.py in status_printer(_, total, desc, ncols)
#     116         # Prepare IPython progress bar
#     117         if IProgress is None:  # #187 #451 #558 #872
# --> 118             raise ImportError(WARN_NOIPYW)
#     119         if total:
#     120             pbar = IProgress(min=0, max=total)
#
# ImportError: IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ### 3D plot of trajectory in (x,y,z)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
phase_l = phase(tlist)
Omega_l = Omega(tlist)
phi_ext_l = phi_ext_t(tlist)
ax.plot(
    Ax*np.cos(angle)*(1-np.cos(omega*tlist)), 
    Ay*np.sin(omega*tlist), 
    Ax*np.sin(angle)*(1-np.cos(omega*tlist))
)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 0, 'z')

# %%
def phi_ext_t(t):  # z
    return Ax*np.sin(angle)*(1-np.cos(omega*t))

def phase(t):  # \phi
    return np.arctan2(
        Ay*np.sin(omega*t),
        Ax*np.cos(angle)*(1-np.cos(omega*t))
    )  # arctan2(y,x)

def Omega(t):  # sqrt(x^2 + y^2)
    return np.sqrt((Ax*np.cos(angle)*(1-np.cos(omega*t)))**2 + (Ay*np.sin(omega*t))**2)

# %% [markdown]
# ### 3D plot of trajectory in (Omega, phi, z)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
phase_l = phase(tlist)
Omega_l = Omega(tlist)
phi_ext_l = phi_ext_t(tlist)
ax.plot(Omega_l*np.cos(phase_l), Omega_l*np.sin(phase_l), phi_ext_l)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
# Text(0.5, 0, 'z')

# %% [markdown]
# ### Adiabatic trajectory calculation (`Transmon` class)

# %% [markdown]
# Adiabatic solution is generated as a sequence of $|e(\vec{\mathbf{R}})\rangle$ eigenstates

# %%
phi_ext_l = phi_ext_l
Amp_d_l = Omega_l
phase_l = phase_l
pars_list = [
    TmonPars(
        Ec, Ej, alpha, alpha1*phi_ext, alpha2*phi_ext,
        gamma_rel, gamma_phi,
        Amp_d, omega_d, phase_d, t
    ) for phi_ext, Amp_d, phase_d, t in zip(phi_ext_l, Amp_d_l, phase_l, tlist)]
tr = Transmon(pars_list, Nc=Nc, res_trunc=3, index=None)

# %% [markdown]
# intensive calculations

# %%
sols = tr.solve()
# Out:
#   0%|                                                                                        | 0/10001 [00:00<?, ?it/s]
#   0%|                                                                              | 16/10001 [00:00<01:02, 158.51it/s]
#   0%|▏                                                                             | 32/10001 [00:00<01:03, 155.78it/s]
#   0%|▎                                                                             | 48/10001 [00:00<01:05, 152.24it/s]
#   1%|▍                                                                             | 64/10001 [00:00<01:04, 153.49it/s]
#   1%|▌                                                                             | 80/10001 [00:00<01:04, 154.72it/s]
#   1%|▋                                                                             | 96/10001 [00:00<01:04, 154.45it/s]
#   1%|▊                                                                            | 113/10001 [00:00<01:02, 157.43it/s]
#   1%|▉                                                                            | 129/10001 [00:00<01:03, 154.42it/s]
#   1%|█                                                                            | 146/10001 [00:00<01:02, 157.73it/s]
#   2%|█▏                                                                           | 162/10001 [00:01<01:02, 157.03it/s]
#   2%|█▎                                                                           | 178/10001 [00:01<01:02, 157.00it/s]
#   2%|█▍                                                                           | 194/10001 [00:01<01:02, 156.07it/s]
#   2%|█▌                                                                           | 211/10001 [00:01<01:02, 157.42it/s]
#   2%|█▋                                                                           | 227/10001 [00:01<01:02, 155.47it/s]
#   2%|█▊                                                                           | 243/10001 [00:01<01:04, 152.37it/s]
#   3%|█▉                                                                           | 259/10001 [00:01<01:04, 151.54it/s]
#   3%|██                                                                           | 275/10001 [00:01<01:04, 150.54it/s]
#   3%|██▏                                                                          | 291/10001 [00:01<01:06, 146.16it/s]
#   3%|██▎                                                                          | 306/10001 [00:02<01:06, 146.85it/s]
#   3%|██▍                                                                          | 322/10001 [00:02<01:04, 149.35it/s]
#   3%|██▌                                                                          | 339/10001 [00:02<01:03, 152.69it/s]
#   4%|██▋                                                                          | 355/10001 [00:02<01:02, 154.38it/s]
#   4%|██▊                                                                          | 371/10001 [00:02<01:02, 153.80it/s]
#   4%|██▉                                                                          | 387/10001 [00:02<01:02, 153.84it/s]
#   4%|███                                                                          | 403/10001 [00:02<01:02, 153.87it/s]
#   4%|███▏                                                                         | 419/10001 [00:02<01:01, 155.23it/s]
#   4%|███▎                                                                         | 435/10001 [00:02<01:02, 153.50it/s]
#   5%|███▍                                                                         | 451/10001 [00:02<01:02, 152.32it/s]
#   5%|███▌                                                                         | 467/10001 [00:03<01:03, 150.64it/s]
#   5%|███▋                                                                         | 483/10001 [00:03<01:03, 149.91it/s]
#   5%|███▊                                                                         | 498/10001 [00:03<01:04, 148.26it/s]
#   5%|███▉                                                                         | 514/10001 [00:03<01:03, 150.37it/s]
#   5%|████                                                                         | 530/10001 [00:03<01:02, 152.74it/s]
#   5%|████▏                                                                        | 547/10001 [00:03<01:00, 155.09it/s]
#   6%|████▎                                                                        | 563/10001 [00:03<01:01, 152.99it/s]
#   6%|████▍                                                                        | 580/10001 [00:03<01:00, 155.24it/s]
#   6%|████▌                                                                        | 596/10001 [00:03<01:01, 153.54it/s]
#   6%|████▋                                                                        | 612/10001 [00:04<01:02, 150.24it/s]
#   6%|████▊                                                                        | 628/10001 [00:04<01:03, 147.99it/s]
#   6%|████▉                                                                        | 644/10001 [00:04<01:02, 150.55it/s]
#   7%|█████                                                                        | 661/10001 [00:04<01:00, 153.94it/s]
#   7%|█████▏                                                                       | 678/10001 [00:04<00:59, 155.90it/s]
#   7%|█████▎                                                                       | 694/10001 [00:04<01:00, 153.14it/s]
#   7%|█████▍                                                                       | 710/10001 [00:04<01:00, 153.37it/s]
#   7%|█████▌                                                                       | 726/10001 [00:04<01:00, 153.54it/s]
#   7%|█████▋                                                                       | 743/10001 [00:04<00:59, 156.51it/s]
#   8%|█████▊                                                                       | 759/10001 [00:04<00:59, 156.19it/s]
#   8%|█████▉                                                                       | 775/10001 [00:05<01:00, 153.31it/s]
#   8%|██████                                                                       | 791/10001 [00:05<01:01, 150.08it/s]
#   8%|██████▏                                                                      | 807/10001 [00:05<01:01, 149.11it/s]
#   8%|██████▎                                                                      | 822/10001 [00:05<01:01, 148.96it/s]
#   8%|██████▍                                                                      | 838/10001 [00:05<01:00, 151.73it/s]
#   9%|██████▌                                                                      | 854/10001 [00:05<01:00, 151.95it/s]
#   9%|██████▋                                                                      | 870/10001 [00:05<01:00, 151.24it/s]
#   9%|██████▊                                                                      | 886/10001 [00:05<01:00, 151.61it/s]
#   9%|██████▉                                                                      | 902/10001 [00:05<01:00, 151.43it/s]
#   9%|███████                                                                      | 918/10001 [00:06<01:00, 151.31it/s]
#   9%|███████▏                                                                     | 934/10001 [00:06<01:00, 149.11it/s]
#   9%|███████▎                                                                     | 949/10001 [00:06<01:01, 147.70it/s]
#  10%|███████▍                                                                     | 965/10001 [00:06<00:59, 150.83it/s]
#  10%|███████▌                                                                     | 981/10001 [00:06<00:59, 151.76it/s]
#  10%|███████▋                                                                     | 998/10001 [00:06<00:57, 155.29it/s]
#  10%|███████▋                                                                    | 1014/10001 [00:06<00:58, 152.68it/s]
#  10%|███████▊                                                                    | 1030/10001 [00:06<00:59, 150.48it/s]
#  10%|███████▉                                                                    | 1046/10001 [00:06<00:58, 152.79it/s]
#  11%|████████                                                                    | 1062/10001 [00:06<00:57, 154.46it/s]
#  11%|████████▏                                                                   | 1078/10001 [00:07<00:57, 155.20it/s]
#  11%|████████▎                                                                   | 1094/10001 [00:07<00:58, 152.17it/s]
#  11%|████████▍                                                                   | 1110/10001 [00:07<00:58, 152.26it/s]
#  11%|████████▌                                                                   | 1126/10001 [00:07<00:58, 151.89it/s]
#  11%|████████▋                                                                   | 1142/10001 [00:07<00:58, 151.63it/s]
#  12%|████████▊                                                                   | 1158/10001 [00:07<00:58, 151.02it/s]
#  12%|████████▉                                                                   | 1174/10001 [00:07<00:57, 152.75it/s]
#  12%|█████████                                                                   | 1190/10001 [00:07<00:57, 154.43it/s]
#  12%|█████████▏                                                                  | 1206/10001 [00:07<00:56, 155.63it/s]
#  12%|█████████▎                                                                  | 1222/10001 [00:08<00:57, 152.46it/s]
#  12%|█████████▍                                                                  | 1238/10001 [00:08<00:58, 150.32it/s]
#  13%|█████████▌                                                                  | 1254/10001 [00:08<00:58, 150.53it/s]
#  13%|█████████▋                                                                  | 1270/10001 [00:08<00:57, 151.97it/s]
#  13%|█████████▊                                                                  | 1287/10001 [00:08<00:56, 154.97it/s]
#  13%|█████████▉                                                                  | 1304/10001 [00:08<00:55, 157.98it/s]
#  13%|██████████                                                                  | 1321/10001 [00:08<00:54, 158.73it/s]
#  13%|██████████▏                                                                 | 1338/10001 [00:08<00:54, 160.17it/s]
#  14%|██████████▎                                                                 | 1355/10001 [00:08<00:53, 160.72it/s]
#  14%|██████████▍                                                                 | 1372/10001 [00:08<00:53, 161.56it/s]
#  14%|██████████▌                                                                 | 1389/10001 [00:09<00:53, 161.69it/s]
#  14%|██████████▋                                                                 | 1406/10001 [00:09<00:52, 162.25it/s]
#  14%|██████████▊                                                                 | 1423/10001 [00:09<00:52, 164.06it/s]
#  14%|██████████▉                                                                 | 1440/10001 [00:09<00:52, 161.57it/s]
#  15%|███████████                                                                 | 1457/10001 [00:09<00:52, 163.56it/s]
#  15%|███████████▏                                                                | 1474/10001 [00:09<00:53, 160.32it/s]
#  15%|███████████▎                                                                | 1491/10001 [00:09<00:52, 162.67it/s]
#  15%|███████████▍                                                                | 1508/10001 [00:09<00:51, 163.40it/s]
#  15%|███████████▌                                                                | 1525/10001 [00:09<00:52, 160.67it/s]
#  15%|███████████▋                                                                | 1542/10001 [00:10<00:52, 159.70it/s]
#  16%|███████████▊                                                                | 1559/10001 [00:10<00:52, 162.22it/s]
#  16%|███████████▉                                                                | 1576/10001 [00:10<00:52, 161.69it/s]
#  16%|████████████                                                                | 1593/10001 [00:10<00:52, 159.51it/s]
#  16%|████████████▏                                                               | 1610/10001 [00:10<00:52, 160.70it/s]
#  16%|████████████▎                                                               | 1627/10001 [00:10<00:52, 158.83it/s]
#  16%|████████████▍                                                               | 1643/10001 [00:10<00:52, 158.29it/s]
#  17%|████████████▌                                                               | 1659/10001 [00:10<00:53, 156.55it/s]
#  17%|████████████▋                                                               | 1675/10001 [00:10<00:53, 155.77it/s]
#  17%|████████████▊                                                               | 1691/10001 [00:10<00:54, 153.46it/s]
#  17%|████████████▉                                                               | 1707/10001 [00:11<00:53, 154.48it/s]
#  17%|█████████████                                                               | 1723/10001 [00:11<00:53, 154.76it/s]
#  17%|█████████████▏                                                              | 1739/10001 [00:11<00:53, 155.41it/s]
#  18%|█████████████▎                                                              | 1755/10001 [00:11<00:52, 155.87it/s]
#  18%|█████████████▍                                                              | 1771/10001 [00:11<00:52, 155.28it/s]
#  18%|█████████████▌                                                              | 1788/10001 [00:11<00:51, 158.23it/s]
#  18%|█████████████▋                                                              | 1805/10001 [00:11<00:51, 160.30it/s]
#  18%|█████████████▊                                                              | 1822/10001 [00:11<00:50, 161.28it/s]
#  18%|█████████████▉                                                              | 1839/10001 [00:11<00:50, 161.97it/s]
#  19%|██████████████                                                              | 1856/10001 [00:11<00:51, 159.67it/s]
#  19%|██████████████▏                                                             | 1873/10001 [00:12<00:50, 161.29it/s]
#  19%|██████████████▎                                                             | 1890/10001 [00:12<00:50, 161.96it/s]
#  19%|██████████████▍                                                             | 1907/10001 [00:12<00:50, 161.51it/s]
#  19%|██████████████▌                                                             | 1924/10001 [00:12<00:49, 163.53it/s]
#  19%|██████████████▊                                                             | 1941/10001 [00:12<00:49, 162.13it/s]
#  20%|██████████████▉                                                             | 1958/10001 [00:12<00:49, 162.56it/s]
#  20%|███████████████                                                             | 1975/10001 [00:12<00:49, 163.32it/s]
#  20%|███████████████▏                                                            | 1992/10001 [00:12<00:49, 162.46it/s]
#  20%|███████████████▎                                                            | 2009/10001 [00:12<00:49, 162.78it/s]
#  20%|███████████████▍                                                            | 2026/10001 [00:13<00:49, 162.08it/s]
#  20%|███████████████▌                                                            | 2043/10001 [00:13<00:50, 158.88it/s]
#  21%|███████████████▋                                                            | 2060/10001 [00:13<00:49, 160.25it/s]
#  21%|███████████████▊                                                            | 2077/10001 [00:13<00:49, 161.69it/s]
#  21%|███████████████▉                                                            | 2094/10001 [00:13<00:48, 162.71it/s]
#  21%|████████████████                                                            | 2111/10001 [00:13<00:49, 160.65it/s]
#  21%|████████████████▏                                                           | 2128/10001 [00:13<00:49, 159.69it/s]
#  21%|████████████████▎                                                           | 2144/10001 [00:13<00:49, 159.35it/s]
#  22%|████████████████▍                                                           | 2161/10001 [00:13<00:48, 160.60it/s]
#  22%|████████████████▌                                                           | 2178/10001 [00:13<00:48, 161.49it/s]
#  22%|████████████████▋                                                           | 2195/10001 [00:14<00:48, 162.11it/s]
#  22%|████████████████▊                                                           | 2212/10001 [00:14<00:47, 162.54it/s]
#  22%|████████████████▉                                                           | 2229/10001 [00:14<00:47, 163.31it/s]
#  22%|█████████████████                                                           | 2246/10001 [00:14<00:47, 163.86it/s]
#  23%|█████████████████▏                                                          | 2263/10001 [00:14<00:47, 163.77it/s]
#  23%|█████████████████▎                                                          | 2280/10001 [00:14<00:47, 163.23it/s]
#  23%|█████████████████▍                                                          | 2297/10001 [00:14<00:47, 162.39it/s]
#  23%|█████████████████▌                                                          | 2314/10001 [00:14<00:47, 163.21it/s]
#  23%|█████████████████▋                                                          | 2331/10001 [00:14<00:46, 164.26it/s]
#  23%|█████████████████▊                                                          | 2348/10001 [00:15<00:46, 165.00it/s]
#  24%|█████████████████▉                                                          | 2365/10001 [00:15<00:46, 164.57it/s]
#  24%|██████████████████                                                          | 2382/10001 [00:15<00:46, 165.22it/s]
#  24%|██████████████████▏                                                         | 2399/10001 [00:15<00:46, 165.20it/s]
#  24%|██████████████████▎                                                         | 2416/10001 [00:15<00:45, 165.18it/s]
#  24%|██████████████████▍                                                         | 2433/10001 [00:15<00:46, 161.87it/s]
#  24%|██████████████████▌                                                         | 2450/10001 [00:15<00:47, 160.53it/s]
#  25%|██████████████████▋                                                         | 2467/10001 [00:15<00:46, 161.89it/s]
#  25%|██████████████████▉                                                         | 2484/10001 [00:15<00:46, 160.55it/s]
#  25%|███████████████████                                                         | 2501/10001 [00:15<00:46, 162.83it/s]
#  25%|███████████████████▏                                                        | 2518/10001 [00:16<00:46, 162.58it/s]
#  25%|███████████████████▎                                                        | 2535/10001 [00:16<00:46, 159.66it/s]
#  26%|███████████████████▍                                                        | 2552/10001 [00:16<00:46, 160.81it/s]Exception ignored in: <function tqdm.__del__ at 0x000002950BEC0AF8>
# Traceback (most recent call last):
#   File "C:\Users\SUNSHINE_MACHINE\.conda\envs\qp-nbs\lib\site-packages\tqdm\std.py", line 1162, in __del__
#     self.close()
#   File "C:\Users\SUNSHINE_MACHINE\.conda\envs\qp-nbs\lib\site-packages\tqdm\notebook.py", line 287, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm_notebook' object has no attribute 'disp'
#
#  26%|███████████████████▌                                                        | 2569/10001 [00:16<01:11, 103.69it/s]
#  26%|███████████████████▋                                                        | 2586/10001 [00:16<01:03, 116.24it/s]
#  26%|███████████████████▊                                                        | 2602/10001 [00:16<00:58, 125.89it/s]
#  26%|███████████████████▉                                                        | 2619/10001 [00:16<00:54, 135.69it/s]
#  26%|████████████████████                                                        | 2636/10001 [00:16<00:51, 143.43it/s]
#  27%|████████████████████▏                                                       | 2653/10001 [00:17<00:49, 148.57it/s]
#  27%|████████████████████▎                                                       | 2670/10001 [00:17<00:47, 153.20it/s]
#  27%|████████████████████▍                                                       | 2687/10001 [00:17<00:46, 156.18it/s]
#  27%|████████████████████▌                                                       | 2704/10001 [00:17<00:45, 158.77it/s]
#  27%|████████████████████▋                                                       | 2721/10001 [00:17<00:45, 160.18it/s]
#  27%|████████████████████▊                                                       | 2738/10001 [00:17<00:45, 161.18it/s]
#  28%|████████████████████▉                                                       | 2755/10001 [00:17<00:45, 160.96it/s]
#  28%|█████████████████████                                                       | 2772/10001 [00:17<00:45, 160.36it/s]
#  28%|█████████████████████▏                                                      | 2789/10001 [00:17<00:44, 161.31it/s]
#  28%|█████████████████████▎                                                      | 2806/10001 [00:18<00:44, 161.97it/s]
#  28%|█████████████████████▍                                                      | 2823/10001 [00:18<00:44, 162.91it/s]
#  28%|█████████████████████▌                                                      | 2840/10001 [00:18<00:43, 163.10it/s]
#  29%|█████████████████████▋                                                      | 2857/10001 [00:18<00:43, 163.24it/s]
#  29%|█████████████████████▊                                                      | 2874/10001 [00:18<00:43, 163.33it/s]
#  29%|█████████████████████▉                                                      | 2891/10001 [00:18<00:43, 163.40it/s]
#  29%|██████████████████████                                                      | 2908/10001 [00:18<00:43, 163.45it/s]
#  29%|██████████████████████▏                                                     | 2925/10001 [00:18<00:43, 163.95it/s]
#  29%|██████████████████████▎                                                     | 2942/10001 [00:18<00:43, 160.58it/s]
#  30%|██████████████████████▍                                                     | 2959/10001 [00:18<00:43, 161.93it/s]
#  30%|██████████████████████▌                                                     | 2976/10001 [00:19<00:43, 161.03it/s]
#  30%|██████████████████████▋                                                     | 2993/10001 [00:19<00:43, 160.40it/s]
#  30%|██████████████████████▊                                                     | 3010/10001 [00:19<00:43, 161.34it/s]
#  30%|███████████████████████                                                     | 3027/10001 [00:19<00:43, 162.00it/s]
#  30%|███████████████████████▏                                                    | 3044/10001 [00:19<00:42, 162.46it/s]
#  31%|███████████████████████▎                                                    | 3061/10001 [00:19<00:42, 162.79it/s]
#  31%|███████████████████████▍                                                    | 3078/10001 [00:19<00:42, 162.08it/s]
#  31%|███████████████████████▌                                                    | 3095/10001 [00:19<00:42, 160.68it/s]
#  31%|███████████████████████▋                                                    | 3112/10001 [00:19<00:42, 161.53it/s]
#  31%|███████████████████████▊                                                    | 3129/10001 [00:20<00:42, 162.13it/s]
#  31%|███████████████████████▉                                                    | 3146/10001 [00:20<00:42, 162.56it/s]
#  32%|████████████████████████                                                    | 3163/10001 [00:20<00:41, 162.86it/s]
#  32%|████████████████████████▏                                                   | 3180/10001 [00:20<00:41, 163.06it/s]
#  32%|████████████████████████▎                                                   | 3197/10001 [00:20<00:41, 163.21it/s]
#  32%|████████████████████████▍                                                   | 3214/10001 [00:20<00:41, 163.79it/s]
#  32%|████████████████████████▌                                                   | 3231/10001 [00:20<00:41, 162.78it/s]
#  32%|████████████████████████▋                                                   | 3248/10001 [00:20<00:41, 163.48it/s]
#  33%|████████████████████████▊                                                   | 3265/10001 [00:20<00:40, 164.45it/s]
#  33%|████████████████████████▉                                                   | 3282/10001 [00:20<00:40, 164.18it/s]
#  33%|█████████████████████████                                                   | 3299/10001 [00:21<00:40, 165.43it/s]
#  33%|█████████████████████████▏                                                  | 3316/10001 [00:21<00:40, 165.34it/s]
#  33%|█████████████████████████▎                                                  | 3333/10001 [00:21<00:40, 165.28it/s]
#  33%|█████████████████████████▍                                                  | 3350/10001 [00:21<00:40, 164.76it/s]
#  34%|█████████████████████████▌                                                  | 3367/10001 [00:21<00:40, 164.40it/s]
#  34%|█████████████████████████▋                                                  | 3384/10001 [00:21<00:40, 165.10it/s]
#  34%|█████████████████████████▊                                                  | 3401/10001 [00:21<00:39, 165.11it/s]
#  34%|█████████████████████████▉                                                  | 3418/10001 [00:21<00:39, 164.64it/s]
#  34%|██████████████████████████                                                  | 3435/10001 [00:21<00:39, 164.79it/s]
#  35%|██████████████████████████▏                                                 | 3452/10001 [00:21<00:39, 163.94it/s]
#  35%|██████████████████████████▎                                                 | 3469/10001 [00:22<00:39, 164.78it/s]
#  35%|██████████████████████████▍                                                 | 3486/10001 [00:22<00:39, 164.89it/s]
#  35%|██████████████████████████▌                                                 | 3503/10001 [00:22<00:39, 164.96it/s]
#  35%|██████████████████████████▋                                                 | 3520/10001 [00:22<00:39, 165.02it/s]
#  35%|██████████████████████████▉                                                 | 3537/10001 [00:22<00:43, 149.01it/s]
#  36%|███████████████████████████                                                 | 3554/10001 [00:22<00:41, 153.51it/s]
#  36%|███████████████████████████▏                                                | 3571/10001 [00:22<00:40, 157.26it/s]
#  36%|███████████████████████████▎                                                | 3588/10001 [00:22<00:40, 159.54it/s]
#  36%|███████████████████████████▍                                                | 3605/10001 [00:22<00:39, 161.64it/s]
#  36%|███████████████████████████▌                                                | 3622/10001 [00:23<00:39, 161.75it/s]
#  36%|███████████████████████████▋                                                | 3639/10001 [00:23<00:39, 162.75it/s]
#  37%|███████████████████████████▊                                                | 3656/10001 [00:23<00:38, 163.46it/s]
#  37%|███████████████████████████▉                                                | 3673/10001 [00:23<00:38, 164.44it/s]
#  37%|████████████████████████████                                                | 3690/10001 [00:23<00:38, 164.65it/s]
#  37%|████████████████████████████▏                                               | 3707/10001 [00:23<00:38, 163.37it/s]
#  37%|████████████████████████████▎                                               | 3724/10001 [00:23<00:38, 163.43it/s]
#  37%|████████████████████████████▍                                               | 3741/10001 [00:23<00:38, 163.94it/s]
#  38%|████████████████████████████▌                                               | 3758/10001 [00:23<00:37, 164.30it/s]
#  38%|████████████████████████████▋                                               | 3775/10001 [00:23<00:37, 164.55it/s]
#  38%|████████████████████████████▊                                               | 3792/10001 [00:24<00:37, 164.25it/s]
#  38%|████████████████████████████▉                                               | 3809/10001 [00:24<00:37, 165.00it/s]
#  38%|█████████████████████████████                                               | 3826/10001 [00:24<00:37, 165.04it/s]
#  38%|█████████████████████████████▏                                              | 3843/10001 [00:24<00:37, 165.55it/s]
#  39%|█████████████████████████████▎                                              | 3860/10001 [00:24<00:37, 165.43it/s]
#  39%|█████████████████████████████▍                                              | 3877/10001 [00:24<00:37, 164.86it/s]
#  39%|█████████████████████████████▌                                              | 3894/10001 [00:24<00:36, 165.43it/s]
#  39%|█████████████████████████████▋                                              | 3911/10001 [00:24<00:37, 163.91it/s]
#  39%|█████████████████████████████▊                                              | 3928/10001 [00:24<00:37, 163.33it/s]
#  39%|█████████████████████████████▉                                              | 3945/10001 [00:25<00:36, 164.35it/s]
#  40%|██████████████████████████████                                              | 3962/10001 [00:25<00:36, 164.11it/s]
#  40%|██████████████████████████████▏                                             | 3979/10001 [00:25<00:36, 163.94it/s]
#  40%|██████████████████████████████▎                                             | 3996/10001 [00:25<00:36, 164.78it/s]
#  40%|██████████████████████████████▍                                             | 4013/10001 [00:25<00:36, 164.41it/s]
#  40%|██████████████████████████████▌                                             | 4030/10001 [00:25<00:36, 164.63it/s]
#  40%|██████████████████████████████▊                                             | 4047/10001 [00:25<00:36, 163.83it/s]
#  41%|██████████████████████████████▉                                             | 4064/10001 [00:25<00:36, 164.70it/s]
#  41%|███████████████████████████████                                             | 4081/10001 [00:25<00:35, 164.83it/s]
#  41%|███████████████████████████████▏                                            | 4098/10001 [00:25<00:35, 164.93it/s]
#  41%|███████████████████████████████▎                                            | 4115/10001 [00:26<00:35, 165.47it/s]
#  41%|███████████████████████████████▍                                            | 4132/10001 [00:26<00:35, 165.37it/s]
#  41%|███████████████████████████████▌                                            | 4149/10001 [00:26<00:35, 165.30it/s]
#  42%|███████████████████████████████▋                                            | 4166/10001 [00:26<00:35, 165.74it/s]
#  42%|███████████████████████████████▊                                            | 4183/10001 [00:26<00:35, 166.04it/s]
#  42%|███████████████████████████████▉                                            | 4200/10001 [00:26<00:34, 166.26it/s]
#  42%|████████████████████████████████                                            | 4217/10001 [00:26<00:34, 165.92it/s]
#  42%|████████████████████████████████▏                                           | 4234/10001 [00:26<00:34, 165.69it/s]
#  43%|████████████████████████████████▎                                           | 4251/10001 [00:26<00:34, 165.52it/s]
#  43%|████████████████████████████████▍                                           | 4268/10001 [00:26<00:34, 165.41it/s]
#  43%|████████████████████████████████▌                                           | 4285/10001 [00:27<00:34, 164.85it/s]
#  43%|████████████████████████████████▋                                           | 4302/10001 [00:27<00:34, 165.42it/s]
#  43%|████████████████████████████████▊                                           | 4319/10001 [00:27<00:34, 163.90it/s]
#  43%|████████████████████████████████▉                                           | 4336/10001 [00:27<00:34, 164.27it/s]
#  44%|█████████████████████████████████                                           | 4353/10001 [00:27<00:34, 165.49it/s]
#  44%|█████████████████████████████████▏                                          | 4370/10001 [00:27<00:34, 165.39it/s]
#  44%|█████████████████████████████████▎                                          | 4387/10001 [00:27<00:34, 164.36it/s]
#  44%|█████████████████████████████████▍                                          | 4404/10001 [00:27<00:34, 162.70it/s]
#  44%|█████████████████████████████████▌                                          | 4421/10001 [00:27<00:34, 162.49it/s]
#  44%|█████████████████████████████████▋                                          | 4438/10001 [00:28<00:34, 162.81it/s]
#  45%|█████████████████████████████████▊                                          | 4455/10001 [00:28<00:34, 160.72it/s]
#  45%|█████████████████████████████████▉                                          | 4472/10001 [00:28<00:34, 162.02it/s]
#  45%|██████████████████████████████████                                          | 4489/10001 [00:28<00:34, 161.09it/s]
#  45%|██████████████████████████████████▏                                         | 4506/10001 [00:28<00:33, 163.22it/s]
#  45%|██████████████████████████████████▎                                         | 4523/10001 [00:28<00:33, 163.79it/s]
#  45%|██████████████████████████████████▌                                         | 4540/10001 [00:28<00:33, 164.20it/s]
#  46%|██████████████████████████████████▋                                         | 4557/10001 [00:28<00:33, 164.48it/s]
#  46%|██████████████████████████████████▊                                         | 4574/10001 [00:28<00:33, 162.32it/s]
#  46%|██████████████████████████████████▉                                         | 4591/10001 [00:28<00:33, 163.16it/s]
#  46%|███████████████████████████████████                                         | 4608/10001 [00:29<00:32, 164.22it/s]
#  46%|███████████████████████████████████▏                                        | 4625/10001 [00:29<00:32, 164.02it/s]
#  46%|███████████████████████████████████▎                                        | 4642/10001 [00:29<00:32, 162.47it/s]
#  47%|███████████████████████████████████▍                                        | 4659/10001 [00:29<00:32, 162.33it/s]
#  47%|███████████████████████████████████▌                                        | 4676/10001 [00:29<00:32, 163.63it/s]
#  47%|███████████████████████████████████▋                                        | 4693/10001 [00:29<00:32, 163.61it/s]
#  47%|███████████████████████████████████▊                                        | 4710/10001 [00:29<00:32, 164.07it/s]
#  47%|███████████████████████████████████▉                                        | 4727/10001 [00:29<00:31, 164.87it/s]
#  47%|████████████████████████████████████                                        | 4744/10001 [00:29<00:32, 161.66it/s]
#  48%|████████████████████████████████████▏                                       | 4761/10001 [00:29<00:32, 159.48it/s]
#  48%|████████████████████████████████████▎                                       | 4778/10001 [00:30<00:32, 161.60it/s]
#  48%|████████████████████████████████████▍                                       | 4795/10001 [00:30<00:31, 163.11it/s]
#  48%|████████████████████████████████████▌                                       | 4812/10001 [00:30<00:31, 162.78it/s]
#  48%|████████████████████████████████████▋                                       | 4829/10001 [00:30<00:31, 162.54it/s]
#  48%|████████████████████████████████████▊                                       | 4846/10001 [00:30<00:31, 164.26it/s]
#  49%|████████████████████████████████████▉                                       | 4863/10001 [00:30<00:31, 163.57it/s]
#  49%|█████████████████████████████████████                                       | 4880/10001 [00:30<00:31, 163.57it/s]
#  49%|█████████████████████████████████████▏                                      | 4897/10001 [00:30<00:31, 162.16it/s]
#  49%|█████████████████████████████████████▎                                      | 4914/10001 [00:30<00:31, 161.65it/s]
#  49%|█████████████████████████████████████▍                                      | 4931/10001 [00:31<00:32, 154.69it/s]
#  49%|█████████████████████████████████████▌                                      | 4948/10001 [00:31<00:31, 158.57it/s]
#  50%|█████████████████████████████████████▋                                      | 4965/10001 [00:31<00:31, 160.03it/s]
#  50%|█████████████████████████████████████▊                                      | 4982/10001 [00:31<00:31, 161.07it/s]
#  50%|█████████████████████████████████████▉                                      | 4999/10001 [00:31<00:31, 160.89it/s]
#  50%|██████████████████████████████████████                                      | 5016/10001 [00:31<00:30, 162.14it/s]
#  50%|██████████████████████████████████████▏                                     | 5033/10001 [00:31<00:30, 161.18it/s]
#  50%|██████████████████████████████████████▍                                     | 5050/10001 [00:31<00:30, 161.88it/s]
#  51%|██████████████████████████████████████▌                                     | 5067/10001 [00:31<00:30, 161.00it/s]
#  51%|██████████████████████████████████████▋                                     | 5084/10001 [00:31<00:30, 161.76it/s]
#  51%|██████████████████████████████████████▊                                     | 5102/10001 [00:32<00:29, 164.22it/s]
#  51%|██████████████████████████████████████▉                                     | 5119/10001 [00:32<00:29, 164.96it/s]
#  51%|███████████████████████████████████████                                     | 5136/10001 [00:32<00:29, 165.02it/s]
#  52%|███████████████████████████████████████▏                                    | 5153/10001 [00:32<00:29, 165.05it/s]
#  52%|███████████████████████████████████████▎                                    | 5170/10001 [00:32<00:29, 163.66it/s]
#  52%|███████████████████████████████████████▍                                    | 5187/10001 [00:32<00:29, 165.05it/s]
#  52%|███████████████████████████████████████▌                                    | 5204/10001 [00:32<00:29, 164.60it/s]
#  52%|███████████████████████████████████████▋                                    | 5221/10001 [00:32<00:29, 164.76it/s]
#  52%|███████████████████████████████████████▊                                    | 5238/10001 [00:32<00:28, 164.40it/s]
#  53%|███████████████████████████████████████▉                                    | 5255/10001 [00:33<00:28, 163.67it/s]
#  53%|████████████████████████████████████████                                    | 5272/10001 [00:33<00:28, 164.11it/s]
#  53%|████████████████████████████████████████▏                                   | 5289/10001 [00:33<00:28, 164.90it/s]
#  53%|████████████████████████████████████████▎                                   | 5306/10001 [00:33<00:28, 164.97it/s]
#  53%|████████████████████████████████████████▍                                   | 5323/10001 [00:33<00:28, 164.07it/s]
#  53%|████████████████████████████████████████▌                                   | 5340/10001 [00:33<00:28, 162.04it/s]
#  54%|████████████████████████████████████████▋                                   | 5357/10001 [00:33<00:28, 162.49it/s]
#  54%|████████████████████████████████████████▉                                   | 5390/10001 [00:33<00:28, 159.16it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Documents\GitHub\Examples\transmon_simulations_lib\single_transmon\transmon.py in solve(self, sparse)
#     164             try:
# --> 165                 solution = self._eigsys_sol_cache[pars_pt]
#     166                 result.append(solution)
#
# KeyError: TmonPars(Ec=0.6, Ej=28, alpha=0.2, phiExt1=0.0009394436460045754, phiExt2=0.002192035174010676, gamma_rel=1e-05, gamma_phi=2e-05, Amp_d=0.006654903810120803, omega_d=6.196019445298354, phase_d=-0.6180324305601623, time=85.67302664687908)
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12892\2907840098.py in <module>
# ----> 1 sols = tr.solve()
#
# ~\Documents\GitHub\Examples\transmon_simulations_lib\single_transmon\transmon.py in solve(self, sparse)
#     169                 n_full = qp.charge(self.Nc)
#     170                 evals, evecs = H_full.eigenstates(
# --> 171                     sparse=sparse, sort="low", eigvals=self.res_trunc
#     172                 )
#     173
#
# ~\.conda\envs\qp-nbs\lib\site-packages\qutip\qobj.py in eigenstates(self, sparse, sort, eigvals, tol, maxiter, phase_fix)
#    1737                               if ket[phase_fix, 0] else 1
#    1738                               for ket in ekets])
# -> 1739         return evals, ekets / norms * phase
#    1740
#    1741     def eigenenergies(self, sparse=False, sort='low',
#
# ~\.conda\envs\qp-nbs\lib\site-packages\qutip\qobj.py in __truediv__(self, other)
#     651
#     652     def __truediv__(self, other):
# --> 653         return self.__div__(other)
#     654
#     655     def __div__(self, other):
#
# ~\.conda\envs\qp-nbs\lib\site-packages\qutip\qobj.py in __div__(self, other)
#     664                               np.integer, np.floating, np.complexfloating)):
#     665             out = Qobj()
# --> 666             out.data = self.data / other
#     667             out.dims = self.dims
#     668             if settings.auto_tidyup:
#
# ~\.conda\envs\qp-nbs\lib\site-packages\scipy\sparse\base.py in __truediv__(self, other)
#     614
#     615     def __truediv__(self, other):
# --> 616         return self._divide(other, true_divide=True)
#     617
#     618     def __div__(self, other):
#
# ~\.conda\envs\qp-nbs\lib\site-packages\scipy\sparse\base.py in _divide(self, other, true_divide, rdivide)
#     581                 return self.astype(np.float_)._mul_scalar(1./other)
#     582             else:
# --> 583                 r = self._mul_scalar(1./other)
#     584
#     585                 scalar_dtype = np.asarray(other).dtype
#
# ~\.conda\envs\qp-nbs\lib\site-packages\scipy\sparse\data.py in _mul_scalar(self, other)
#     122
#     123     def _mul_scalar(self, other):
# --> 124         return self._with_data(self.data * other)
#     125
#     126
#
# ~\.conda\envs\qp-nbs\lib\site-packages\qutip\fastsparse.py in _with_data(self, data, copy)
#     353         data = np.asarray(data, dtype=complex)
#     354         if copy:
# --> 355             return fast_csr_matrix((data,self.indices.copy(),self.indptr.copy()),
#     356                                    shape=self.shape,dtype=data.dtype)
#     357         else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Direct numerical solution (does not have adiabatic properties for computationally available dR/dt -> 0)

# %% [markdown]
# initial state is $|e(\phi_{ext}=\Omega=0)\rangle$

# %%
phi0 = 0
pars_list = [TmonPars(Ec, Ej, alpha, phi0, phi0, gamma_rel, gamma_phi)]
tr = Transmon(pars_list, Nc=Nc, res_trunc=3, index=None)

sols = tr.solve()
psi0 = sols[0].e_state()
psi0
# Out:
# Quantum object: dims = [[21], [1]], shape = (21, 1), type = ket
# Qobj data =
# [[-2.68386339e-04]
#  [ 1.34619774e-03]
#  [-5.57050904e-03]
#  [ 1.94328085e-02]
#  [-5.65069480e-02]
#  [ 1.34841380e-01]
#  [-2.58661007e-01]
#  [ 3.86592088e-01]
#  [-4.24020086e-01]
#  [ 2.86465051e-01]
#  [ 0.00000000e+00]
#  [-2.86465051e-01]
#  [ 4.24020086e-01]
#  [-3.86592088e-01]
#  [ 2.58661007e-01]
#  [-1.34841380e-01]
#  [ 5.65069480e-02]
#  [-1.94328085e-02]
#  [ 5.57050904e-03]
#  [-1.34619774e-03]
#  [ 2.68386339e-04]]

# %% [markdown]
# anharmonicity

# %%
anh = np.abs(sols[0].anharmonicity())

# %% [markdown]
# Parameters are measured in units of anharmonicity

# %%
Ax = 20e-3*anh
Ay = 10e-2*anh
v_adiab = 0.001*(1/anh)
omega = v_adiab*2*np.pi
omega_d = sols[0].evals[1]
angle = np.pi/6  # 30 degree

# %%
tlist = np.linspace(0, 0.1 * 2*np.pi/omega, 10001)

# %%
def fr_t(t, args_dict):
    alpha1 = args_dict["alpha1"]
    alpha2 = args_dict["alpha2"]
    phi_ext = phi_ext_t(t)
    return 1/2*np.exp(-1j*alpha1*phi_ext)+alpha*np.exp(-1j*alpha2*phi_ext)

def fl_t(t, args_dict):
    alpha1 = args_dict["alpha1"]
    alpha2 = args_dict["alpha2"]
    phi_ext = phi_ext_t(t)
    return 1/2*np.exp(1j*alpha1*phi_ext)+alpha*np.exp(1j*alpha2*phi_ext)

def fc_t(t, args_dict):
    return Omega(t)*np.cos(omega_d*t + phase(t))

n = qp.charge(Nc)
Hc = Ec*(n**2)
H = [
    Hc,
    [n, fc_t],
    [-Ej*raising_op(dims), fr_t],
    [-Ej*lowering_op(dims), fl_t]
]

# %% [markdown]
# evolution period

# %%
T = 2*np.pi/omega
T  # ns
# Out:
# 158.9481013856755

# %%
args_dict = {
    "alpha1": 1.0,
    "alpha2": 0.0
}
try:
   res = qp.sesolve(H, psi0, tlist, args=args_dict, progress_bar=True)
except Exception as e:
    print(e)
# Out:
# 10.0%. Run time:   0.53s. Est. time left: 00:00:00:04
# 20.0%. Run time:   1.05s. Est. time left: 00:00:00:04
# 30.0%. Run time:   1.58s. Est. time left: 00:00:00:03
# 40.0%. Run time:   2.10s. Est. time left: 00:00:00:03
# 50.0%. Run time:   2.64s. Est. time left: 00:00:00:02
# 60.0%. Run time:   3.17s. Est. time left: 00:00:00:02
# 70.0%. Run time:   3.69s. Est. time left: 00:00:00:01
# 80.0%. Run time:   4.22s. Est. time left: 00:00:00:01
# 90.0%. Run time:   4.74s. Est. time left: 00:00:00:00
# Total run time:   5.27s

# %%
deviation = np.array([np.abs(vec.overlap(psi0)) for vec in res.states])
fig, ax = plt.subplots(1,1)
ax.plot(tlist, 1-deviation)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
fig, ax = plt.subplots(1,1)
deviation_fft = np.fft.fftshift(np.fft.fft(deviation))
freqs = np.fft.fftshift(np.fft.fftfreq(len(deviation), d=1/(tlist[1]-tlist[0])))
ax.plot(freqs, np.abs(deviation_fft))
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %% [markdown]
# ### RWA numerical solution

# %% [markdown]
# $$ H/\hbar = E_C n^2 - E_{J1}\cos{(\phi - \alpha_1 \phi_{ext})} - E_{J2}\cos{(\phi - \alpha_2 \phi_{ext})} + n g \Omega \cos{(\omega_d t + \varphi_d)}$$
# $$ H_0 = diag(0, -\omega_d, -2\omega_d, ...,  -n\omega_d) $$

# %% [markdown]
# operator $\hat{n}$ in eigenbasis:
# $$\hat{n} =
# \left(
# \begin{matrix}
# 0 & n_{01} & 0 & n_{03} & \dots \\
# n_{01} & 0 & n_{12} & 0 & \dots \\
# 0 & n_{12} & 0 & n_{23} & \dots \\
# n_{03} & 0 & n_{23} & 0 & \dots \\
# \vdots & \vdots & \vdots & \vdots & \ddots
# \end{matrix}\right)
# $$

# %% [markdown]
# after transformation into interaction pictrure with $H_0$ above:
# $$e^{i H_0 t} \hat{n} e^{- i H_0 t} =
# \left(
# \begin{matrix}
# 0 & n_{01}e^{i \omega_d t} & 0 & n_{03}e^{3 i \omega_d t} & \dots \\
# n_{01}e^{-i \omega_d t} & 0 & n_{12}e^{i \omega_d t} & 0 & \dots \\
# 0 & n_{12}e^{-i \omega_d t} & 0 & n_{23}e^{i \omega_d t} & \dots \\
# n_{03}e^{-3 i \omega_d t} & 0 & n_{23}e^{-i \omega_d t} & 0 & \dots \\
# \vdots & \vdots & \vdots & \vdots & \ddots
# \end{matrix}
# \right)
# $$

# %%
def fr_t(t, args_dict):
    alpha1 = args_dict["alpha1"]
    alpha2 = args_dict["alpha2"]
    phi_ext = phi_ext_t(t)
    return np.exp(-1j*alpha1*phi_ext)+alpha*np.exp(-1j*alpha2*phi_ext)

def fl_t(t, args_dict):
    alpha1 = args_dict["alpha1"]
    alpha2 = args_dict["alpha2"]
    phi_ext = phi_ext_t(t)
    return np.exp(1j*alpha1*phi_ext)+alpha*np.exp(1j*alpha2*phi_ext)

def fc_t(t, args_dict):
    return Omega(t)*np.cos(omega_d*t + phase(t))

n = qp.charge(Nc)
Hc = Ec*n**2
H = [
    Hc,
    [n, fc_t],
    [-Ej*raising_op(dims), fr_t],
    [-Ej*lowering_op(dims), fl_t]
]

# %% [markdown]
# initial state is $|e(\phi_{ext}=\Omega=0)\rangle$

# %% [markdown]
# # Time domain qp.mesolve

# %%
def fl_t(t, args):
    w = args["pulse_omega"]
    phase_amp = args["phase_amp"]
    alpha = args["alpha"]
    Ej_l = alpha*args["Ej"]
    return Ej_l*np.exp(-1j*phase_amp*np.sin(w*t))/2

def fr_t(t, args):
    w = args["pulse_omega"]
    phase_amp = args["phase_amp"]
    alpha = args["alpha"]
    Ej_r = args["Ej"]
    return Ej_r*np.exp(1j*phase_amp*np.sin(w*t))/2

H0 = Ec*qp.charge(Nc)**2
H1 = qp.Qobj(raising_op(dims))
H2 = qp.Qobj(lowering_op(dims))
H_list_callback = [H0, [H1, fl_t], [H2, fr_t]]
rho_0 = qp.ket2dm(sols1[0].e_state())
tlist = np.linspace(0,20,201)

# %%
sols1[0].e_state()

# %%
args_dict = {
    "pulse_omega": 2e-3,  # GHz
    "phase_amp": np.pi/4,
    "alpha": alpha,
    "Ej": Ej
}
sesolve_res = qp.sesolve(H_list_callback, sols1[0].e_state(), tlist, args=args_dict, progress_bar=True)

# %%
sesolve_res.states[1]

# %%
b3d = qp.Bloch3d()

# %%
for mul in np.linspace(-1,2, 4):
    # phi_ext pulse shape
    for phi_ext in phi_ext_list:
        pars = TmonPars(
            Ec=0.6, Ej=28, alpha=0.2,
            phiExt1=mul*phi_ext, phiExt2=(mul - 1)*phi_ext,
            gamma_rel=0.1e-3,  # GHz
            gamma_phi=0.5e-3,  # GHz
        )
        pars_list.append(pars)
    tr = Transmon(pars=pars_list, Nc=Nc, res_trunc=res_trunc)

# %%
from transmon_simulations_lib.custom_ops import raising_op, lowering_op

# %% [markdown]
# # Z-gate

# %%
import transmon_simulations_lib.single_transmon.transmon
reload(transmon_simulations_lib.single_transmon.transmon)
from transmon_simulations_lib.single_transmon.transmon import Transmon

# %%
import scipy.signal
def gauss(t, t0, gdt):
    import scipy.stats
    gauss_hat_centered = scipy.stats.norm(t0, gdt).pdf(t)
    return gauss_hat_centered

def phi(t, start, tau, gdt):
    phi = np.zeros(t.shape)
    phi[((t > start) & (t < start + tau))] = 1
    if gdt != 0:
        phi = scipy.signal.convolve(phi,gauss(t, t[-1]/2, gdt),mode='same')
    return phi

# %%
fix, ax = plt.subplots(1,1)
pdata = gauss(Ts,Ts[-1]/2, 2)
ax.plot(pdata)
scipy.integrate.quad(lambda x: gauss(x,Ts[-1]/2,2), Ts[-1]/2 - 4, Ts[-1]/2 + 4)

# %% [markdown]
# pulse preparation

# %%
tau = 100  # Gate length
dgt = 12   # typical rise-fall time of the pulse
t_rise = 3*dgt  # several rise-fall times to ensure most pulse is in window
t_start = t_rise  # severak rise-fall times
Ts = np.linspace(0,t_rise + tau + t_rise,1001)
phi_list = phi(Ts, t_start, tau, dgt)
phi_list *= np.pi/16/np.max(phi_list)
fig, ax = plt.subplots(1,1, figsize=(4,3))
ax.plot(Ts, phi_list)
ax.set_xlabel("ns")
ax.set_ylabel("rad")
fig.tight_layout()

# %% [markdown]
# ### Case I

# %%
tr = Transmon(Ec1, Ej1, alpha=alpha, phi=0, Nc=10)
first_evecs_N = 5
first_evecs = tr.solve()[0].evecs[:first_evecs_N]
H_list = [tr.calc_Hfull_cb(phi) for phi in phi_list]
def H_callback(t, *args):
    i = np.argmin(np.abs(t-Ts))
    return H_list[i]
def H_0_callback(t, *args):
    return H_list[0]
sol = qp.sesolve(H_callback, psi1, Ts, options=qp.Options(nsteps=10000))

# %%
fig, ax = plt.subplots(1,1)

projs = []
for evec in first_evecs:
    bra_vec = evec.dag()
    projs.append(np.array([(bra_vec*state_ket)[0,0] for state_ket in sol.states]))
projs = np.array(projs)

for i, proj in enumerate(projs):
    label_str = r"$P_{1 \rightarrow " + f"{i}" + r" }$"
    ax.plot(Ts, np.abs(proj)**2, label=label_str)
s = np.sum(np.abs(projs)**2, axis=0)
ax.plot(Ts, s, label="total population of first \n" + str(len(projs)) + r" eigenstates in $\phi_{ext} = 0$ basis")
ax.legend()
ax.set_xlabel("ns")
ax.set_ylim(-0.05, 1.05)

# %% [markdown]
# ### Case II

# %%
tr = Transmon(Ec1, Ej1, alpha=alpha, phi=0, Nc=10)
first_evecs_N = 5
first_evecs = tr.solve()[0].evecs[:first_evecs_N]
H_list = [tr.calc_Hfull_cb2(phi) for phi in phi_list]
def H_callback(t, *args):
    i = np.argmin(np.abs(t-Ts))
    return H_list[i]
def H_0_callback(t, *args):
    return H_list[0]
sol = qp.sesolve(H_callback, psi1, Ts, options=qp.Options(nsteps=10000))

# %%
fig, ax = plt.subplots(1,1)

projs = []
for evec in first_evecs:
    bra_vec = evec.dag()
    projs.append(np.array([(bra_vec*state_ket)[0,0] for state_ket in sol.states]))
projs = np.array(projs)

for i, proj in enumerate(projs):
    label_str = r"$P_{1 \rightarrow " + f"{i}" + r" }$"
    ax.plot(Ts, np.abs(proj)**2, label=label_str)
s = np.sum(np.abs(projs)**2, axis=0)
ax.plot(Ts, s, label="total population of first \n" + str(len(projs)) + r" eigenstates in $\phi_{ext} = 0$ basis")
ax.legend()
ax.set_xlabel("ns")
ax.set_ylim(-0.05, 1.05)

# %% [markdown]
# # Not sorted

# %%
# qubit 1 jumps from phi = 0 to phi = pi/2 and back
# qubit 2 resides in phi = pi/2
phi_list_cache = np.linspace(0, np.pi/2, int(1e2))

if __name__ == '__main__':
    mp.freeze_support()
    args = []
from single_transmon.transmon import foo
def foo(args):
    return args["phi_offset"]
for phi in phi_list_cache:
    args.append({"phi_offset": phi})
with mp.Pool(mp.cpu_count()-1) as p:
    res = list(p.map(foo, tqdm.tqdm(args)))

# %%
chain = TransmonChain(4, transmon_truncation = 3)
chain.set_phi((params['phi_base_level'] + params['phi_offset'],params['phi2z_base_level'],0.6,0.7))
chain._transmons = [tr1, tr2,tr3,tr4]
chain.set_J([0.01/1.2**2 * 2 * np.pi/5, 0.01/1.2**2 * 2 * np.pi/5, 0.01/1.2**2 * 2 * np.pi/5, 0.01/1.2**2 * 2 * np.pi/5])
chain.build_low_energy_kets(2,0)
chain._Ts = Ts
rho0 = [ket2dm(basis(3,0)),ket2dm(basis(3,0)),ket2dm(basis(3,0)),ket2dm(basis(3,0))]
rho0 = tensor(*rho0)
rho0 = chain.truncate_to_low_population_subspace(rho0)
chain.rho0 = rho0
sigma_z_chain = []
sigma_x_chain = []
sigma_y_chain = []
for i in range (4): #TO DO - вынести в функцию класса
    sigma_z = chain._transmons[i].sz()
    sigma_x = chain._transmons[i].sx()
    sigma_y = chain._transmons[i].sy()
    oper_z = chain._identity_array.copy()
    oper_z[i]=sigma_z
    oper_x = chain._identity_array.copy()
    oper_x[i]=sigma_x
    oper_y = chain._identity_array.copy()
    oper_y[i]=sigma_y
    sigma_z_chain.append(chain.truncate_to_low_population_subspace(tensor(*oper_z)))
    sigma_x_chain.append(chain.truncate_to_low_population_subspace(tensor(*oper_x)))
    sigma_y_chain.append(chain.truncate_to_low_population_subspace(tensor(*oper_y)))

chain.e_ops = sigma_z_chain + sigma_x_chain + sigma_y_chain

# %% [markdown]
# # Свободная эволюция системы

# %% [markdown]
# ### 1й и 2й кубит в цепочке в резонансе, изначально первый кубит возбуждён

# %%
rho0 = [ket2dm(basis(3,0)),ket2dm(basis(3,0)),ket2dm(basis(3,0)),ket2dm(basis(3,0))]
rho0[0] = ket2dm((basis(3,1) + basis(3,0))/sqrt(2)) # задаём начальное состояние 1го кубита
rho0 = tensor(*rho0)
rho0 = chain.truncate_to_low_population_subspace(rho0)
waveform1_const = ones_like(Ts)*(params['phi_base_level']+params['phi_offset'])
waveform2_const = ones_like(Ts)*(params['phi2z_base_level'])
waveform3_const = ones_like(Ts)*0.6
waveform4_const = ones_like(Ts)*0.7


H_full_test = chain.build_H_full([waveform1_const, waveform2_const, waveform3_const, waveform4_const], 
                                 params, [[0,0],[0,0],[0,0],[0,0]] )

result = mesolve(H_full_test, rho0, Ts, 
                 c_ops = [],e_ops = chain.e_ops,
                 progress_bar=True,options=Options(nsteps = 20000, store_states = True, max_step = 1e-1))

# %%
chain.plot_chain_dynamic(result)

# %% [markdown]
# ## Эволюция под действием внешнего поля

# %% [markdown]
# ### Кубиты не в резонансе, поле действует на первый и третий кубиты

# %%
chain.set_phi((params['phi_base_level'],params['phi2z_base_level'],0.6,0.7))

# %%
waveform1_const = ones_like(Ts)*(params['phi_base_level'])
waveform2_const = ones_like(Ts)*(params['phi2z_base_level'])
waveform3_const = ones_like(Ts)*0.6
waveform4_const = ones_like(Ts)*0.7

# %%
H_full = chain.build_H_full([waveform1_const, waveform2_const, waveform3_const, waveform4_const], 
                                 params, [[T._pi_duration,0],[0,0],[T._pi_duration/2,0],[0,0]] )

result = mesolve(H_full, chain.rho0, Ts, 
                 c_ops = [],e_ops = chain.e_ops,
                 progress_bar=True,options=Options(nsteps = 20000, store_states = True, max_step = 1e-1))

chain.plot_chain_dynamic(result)

# %% [markdown]
# ### 1й, 2й и 3й кубиты в резонансе, поле действует на первый

# %%
waveform1_const = ones_like(Ts)*(params['phi_base_level'] + params['phi_offset'] )
waveform2_const = ones_like(Ts)*(params['phi2z_base_level'])
waveform3_const = ones_like(Ts)*(params['phi2z_base_level'])
waveform4_const = ones_like(Ts)*0.7
chain.set_phi((params['phi_base_level'] + params['phi_offset'],params['phi2z_base_level'],params['phi2z_base_level'],0.7))

H_full = chain.build_H_full([waveform1_const, waveform2_const, waveform3_const, waveform4_const], 
                                 params, [[T._pi_duration,0],[0,0],[0,0],[0,0]] )

result = mesolve(H_full, chain.rho0, Ts, 
                 c_ops = [],e_ops = chain.e_ops,
                 progress_bar=True,options=Options(nsteps = 20000, store_states = True, max_step = 1e-1))

chain.plot_chain_dynamic(result)

# %% [markdown]
# ## Vacuum rabi oscillations

# %% [markdown]
# Приготавливаем первый кубит в возбуждённом состоянии, затем на какое-то время перестраиваем его по потоку. При попадании в резонанс со вторым кубитом наблюдаются осцилляции заселённости возбуждённого состояния 1-го и 2-го кубитов. Можно построить зависимость заселённости второго кубита от отстройки по потоку и времени взаимодействия.

# %%
signal = ZPulse(Ts,params)
chain.set_phi((params['phi_base_level'],params['phi2z_base_level'],0.6,0.7))

# %% [markdown]
# ## Форма потокового импульса, подающегося на первый кубит (для одного значения параметров)

# %%
figure()
plot(Ts, vacuum_rabi_waveform(200, 0.03, Ts, params)[0])

# %%
##special for windows 
durations = linspace (50, 250, 50)
phis = linspace (0.025, 0.035, 200)
size = len(phis)
args = []
for ind, phi in enumerate (phis):
    dict_arg = {'chain' : chain, 'params' : params, 'durations' : durations, 'phi_offset' : phi}
    args.append(dict_arg)
    
if __name__=='__main__':
    with Pool(4) as p:
        populations = p.map(vacuum_rabi_populations_one_phi_windows, tqdm(args))

# %%
figure()
pcolormesh(durations, phis, populations)
colorbar()
#savefig('01.12.2021_vacuum_rabi_4q.png')

# %% [markdown]
# ## Iswap Gate

# %% [markdown]
# Пример эволюции кубитов при проведении гейта i-swap, первый кубит изначально переводится в состояние на экваторе сферы блоха,
# далее первый и второй кубиты переводятся в резонанс, после этого проводится фазовая коррекция с помощью Z-гейта.

# %%
rho0 = [ket2dm(basis(3,0)),ket2dm(basis(3,0)),ket2dm(basis(3,0)),ket2dm(basis(3,0))]
rho0 = tensor(*rho0)
rho0 = chain.truncate_to_low_population_subspace(rho0)
chain.set_phi((params['phi_base_level'],params['phi2z_base_level'],0.6,0.7))
chain.set_J([0.01/1.2**2 * 2 * np.pi/5, 0,0,0])
signal = ZPulse(Ts,params)
waveform1 = signal.waveform_iswap_zgate(1)
waveform2 = signal.waveform_iswap_zgate(2)
waveform3_const = ones_like(Ts)*0.6
waveform4_const = ones_like(Ts)*0.7
H_full = chain.build_H_full([waveform1, waveform2, waveform3_const, waveform4_const], 
                                 params, [[T._pi_duration/2,0],[0,0],[0,0],[0,0]] )

result = mesolve(H_full, chain.rho0, Ts, 
                 c_ops = [],e_ops = chain.e_ops,
                 progress_bar=True,options=Options(nsteps = 20000, store_states = True, max_step = 1e-1))

chain.plot_chain_dynamic(result)

# %% [markdown]
# ## Спектр системы в зависимости от потока через первый кубит

# %%
levels = []

phis = linspace(0, 1, 3000)
for phi in tqdm(phis):
    phi_arr = [0.25, .5 , .6, .7]
    phi_arr[0] = phi
    chain.set_phi(phi_arr)
    waveform1_const = ones_like(Ts)*phi_arr[0]
    waveform2_const = ones_like(Ts)*phi_arr[1]
    waveform3_const = ones_like(Ts)*phi_arr[2]
    waveform4_const = ones_like(Ts)*phi_arr[3]
    H_full = chain.build_H_full([waveform1_const, waveform2_const, waveform3_const, waveform4_const], 
                                 params, [[0,0],[0,0],[0,0],[0,0]])
    H_const = chain.truncate_to_low_population_subspace(chain._zero_op)
    for i in range (12):
        if (i%3 != 2):
            H_const+=H_full[i][0]*H_full[i][1][0]
    for i in range(13,19,1):
        H_const+=H_full[i][0]
    evals, evecs = H_const.eigenstates()
    levels.append((evals-evals[0])/2/pi)

# %%
figure()
plot(phis, array(levels)[:, 1:6])
plot(phis, array(levels)[:, 6:21]/2, "--")
